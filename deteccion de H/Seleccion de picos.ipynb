# %% [markdown]
# ### Importando espectro

# %%
import pandas as pd

# %%
data_path = 'C:/Users/gomez/Documents/LIBS/Data/Calibracion Zr2.5Nb - 4.53 J- 2.92us/ARG-1/a1.ols'

# %%
df = pd.read_csv(data_path, delimiter = "\t", skiprows = 6)
df
# Out:
#       Wavelength  Counts
# 0      198.77501     2.4
# 1      198.83018    -4.6
# 2      198.88535     8.4
# 3      198.94051     0.4
# 4      198.99567    -0.6
# ...          ...     ...
# 5919   511.31893    11.3
# 5920   511.37340     8.3
# 5921   511.42785     0.3
# 5922   511.48230     7.3
# 5923   511.53674     8.3
#
# [5924 rows x 2 columns]

# %% [markdown]
# ### Grafico de inspeccion

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
fig = plt.figure()
f1 = fig.add_subplot(1, 1, 1)
f1.plot('Wavelength', 'Counts', data=df)
f1.set_xlabel('Wavelength (nm)')
f1.set_ylabel('Intensity')
fig.set_size_inches(12, 6)

# %%
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x = df['Wavelength'], y = df['Counts'], mode = 'lines', name = 'hola'))
fig.update_layout(
        title = "Mean spectrum for each class",
        xaxis_title = "Wavelength (nm)",
        yaxis_title = "Relative intensity (-)"
)
fig.show()
# Out:
# <div>                            <div id="41951034-a3d7-47b4-b738-758e9505500c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41951034-a3d7-47b4-b738-758e9505500c")) {                    Plotly.newPlot(                        "41951034-a3d7-47b4-b738-758e9505500c",                        [{"mode": "lines", "name": "hola", "type": "scatter", "x": [198.77501, 198.83018, 198.88535, 198.94051, 198.99567, 199.05083, 199.10598, 199.16113, 199.21627, 199.27141, 199.32654, 199.38167, 199.43679, 199.49191, 199.54703, 199.60214, 199.65725, 199.71235, 199.76745, 199.82254, 199.87763, 199.93271, 199.98779, 200.04287, 200.09794, 200.15301, 200.20807, 200.26313, 200.31818, 200.37323, 200.42828, 200.48332, 200.53835, 200.59339, 200.64841, 200.70344, 200.75845, 2
# ...
